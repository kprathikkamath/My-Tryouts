# %%
import pyautogui as gui

# %%
gui.size()
# Out:
# Size(width=1366, height=768)

# %%
gui.position()
# Out:
# Point(x=379, y=15)

# %%
gui.click(x=112, y=186,duration=3)

# %%
gui.moveTo(x=112, y=186,duration=5 )

# %%
gui.position()
# Out:
# Point(x=386, y=52)

# %%
gui.click(x=369, y=0)
gui.click(x=386, y=52)
gui.typewrite('google')

# %%
A=gui.KEYBOARD_KEYS

# %%
gui.hotkey('ctrl','p')

# %%
gui.press('enter')

# %%
gui.screenshot('d:\\Mtech\Hi.png')
# Out:
# <PIL.Image.Image image mode=RGB size=1366x768 at 0x63BBDC0>

# %%
a=gui.locateOnScreen("d:\\Mtech\Capture.JPG")
print(a)
# Out:
# Box(left=235, top=287, width=872, height=65)

# %%
a=gui.locateCenterOnScreen("d:\\Mtech\Capture.JPG")
print(a)
# Out:
# Point(x=671, y=319)

# %%
a=gui.locateCenterOnScreen("d:\\Mtech\\Video Courses\\Udemy\\2.Automate the Boring Stuff with Python\To Xerox\C.JPG")
print(a)
# Out:
# Point(x=504, y=216)
